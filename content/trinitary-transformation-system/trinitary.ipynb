# %% [markdown]
# ## Foundational Principles
#
# ### 1. Universality
#
# - **Rule-Based on Observation**: The system gains universal applicability by being based on the fundamental act of observation, which is a ubiquitous process across different systems—be it physical, biological, or informational.
#
# ### 2. Simplicity
#
# - **Trinitarian Structure**: The "three pillars" (subject, object, environment) form the skeletal structure upon which transformations happen. This trinitarian structure can be seen as the simplest architecture that accommodates the complexities of perception.
#
# - **Five-Step Transformation**: The five steps (absorb, transduce, decide, mediate, radiate) offer a minimal yet comprehensive grammar for describing transformations. The ability to describe non-repeating Penrose tilings suggests a rich potential for complexity arising from simplicity.
#
# ### 3. Adaptivity (To be explored)
#
# - This principle needs more exploration, particularly in the context of how the system adapts or modifies its rules based on feedback or environmental changes.
#
# ## Mathematical Formalization Ideas
#
# ### 1. Trinitarian Structure
#
# For the "three pillars" (subject, object, environment), we could represent each entity as a vector in a multidimensional space, or even as nodes in a network. The edges between them could represent interactions or relationships.
#
# \[
# \text{Pillars: } S = \text{Subject}, O = \text{Object}, E = \text{Environment}
# \]
#
# ### 2. Five-Step Transformation
#
# Each of the five steps (absorb, transduce, decide, mediate, radiate) can be represented as functions that map the state vectors of the pillars to a new state.
#
# - Absorb: \( A(S, O, E) \rightarrow S' \)
# - Transduce: \( T(S, O, E) \rightarrow O' \)
# - Decide: \( D(S, O, E) \rightarrow E' \)
# - Mediate: \( M(S, O, E) \rightarrow (S', O') \)
# - Radiate: \( R(S, O, E) \rightarrow (O', E') \)
#
# These functions could be deterministic or stochastic, depending on the level of complexity needed.
#
# ## 3. Adaptivity
#
# The adaptivity of the system could be modeled as a feedback loop that modifies one or more of the transformation functions based on some criteria, maybe using concepts from control theory.
#
# \[
# \text{Feedback:} F(S, O, E, S', O', E') \rightarrow (A', T', D', M', R')
# \]
#
# Certainly, using OD (Observational Dynamics) and OND (Observational Network Dynamics) tools would bring a unified and rigorous approach to formalizing these concepts. Here's how we can integrate them:
#
# ## Observational Dynamics (OD)
#
# 1. **Three Pillars as Observers**: In OD, we can consider the three pillars (Subject, Object, Environment) as observer agents with their own state vectors. They can interact through thermodynamic-like exchanges of information or energy.
#
# 2. **Information Flow as Observational Dynamics**: The five-step transformations can be modeled as thermodynamic processes, with each step being a specific type of interaction that modifies the state vectors in a defined way.
#
# ## Observational Network Dynamics (OND)
#
# 1. **Network Nodes for Pillars**: Each pillar can be a node in an OND network, with state vectors that evolve over time.
#
# 2. **Transformation Functions as Couplings**: The transformation functions (absorb, transduce, etc.) can be modeled as coupling functions between the nodes in OND. These can be expressed as differential equations that modify the state vectors.
#
# 3. **Feedback as Observer Influence**: In OND, observer nodes can influence other nodes. This can model the adaptive nature of the system, where feedback influences future transformations.
#
# ## Mathematical Steps
#
# 1. **Define OND Model**: Incorporate the three pillars and the transformations as nodes and coupling functions in an OND model.
#
# \[
# \frac{dS}{dt} = A(S, O, E), \quad \frac{dO}{dt} = T(S, O, E), \quad \frac{dE}{dt} = D(S, O, E)
# \]
#
# 2. **Include Observational Dynamics**: Use OD principles to provide a thermodynamic interpretation of the transformations and state changes.
#
# 3. **Non-Repeating Patterns**: Incorporate conditions or constraints into the OND model to ensure the emergence of non-repeating Penrose tilings.
#
# 4. **Simulation and Validation**: Use computational tools to simulate the OND model and validate whether it captures the principles of trinitarian structure and five-step transformations.
#
# 5. **Feedback and Adaptivity**: Include feedback mechanisms to adapt the transformation functions based on the state of the system, possibly introducing new OD or OND elements to capture this.
#
# Absolutely. Let's work through this systematically. We'll start by defining the formal structure for the Observational Dynamics (OD) and Observational Network Dynamics (OND) components, and then move towards integrating them.
#
# Certainly, let's begin the detailed exploration of each step, starting with the definition of the OD components for the three pillars.
#
# ### Step 1: Define OD Components for Three Pillars
#
# We can define each pillar as a state vector:
#
# \[
# S(t) = [s_1(t), s_2(t), \ldots, s_D(t)]^T \\
# O(t) = [o_1(t), o_2(t), \ldots, o_D(t)]^T \\
# E(t) = [e_1(t), e_2(t), \ldots, e_D(t)]^T
# \]
#
# Here, \(D\) is the dimension of the state vector, and \(T\) indicates the transpose of the vector. The dynamics of each state vector will be governed by a set of stochastic differential equations.
#
# ### Step 2: Define OND Network Nodes and Edges for Pillars
#
# The OND model treats each pillar as a node in a network. Thus, we have:
#
# \[ V = \{S, O, E\} \]
#
# And the edges, representing the information flow between them, are:
#
# \[ E = \{(S, O), (O, E), (E, S)\} \]
#
# ### Step 3: Define Transformation Functions as OND Couplings
#
# The transformation functions can be represented as coupling functions between the nodes. Let's define them:
#
# - Absorb: \( f_{SO}(S, O) \)
# - Transduce: \( f_{OE}(O, E) \)
# - Decide: \( f_{ES}(E, S) \)
# - Mediate and Radiate can be considered as additional transformations or as part of these basic ones, depending on the level of detail we want.
#
# For simplicity, let's use linear coupling functions:
#
# \[
# f_{SO}(S, O) = \alpha \cdot (S - O) \\
# f_{OE}(O, E) = \beta \cdot (O - E) \\
# f_{ES}(E, S) = \gamma \cdot (E - S)
# \]
#
#
# ### Step 1: Mathematical Formulation of State Vectors
#
# For the Subject (S), Object (O), and Environment (E), we can define state vectors as:
#
# \[
# S(t) = [s_1(t), s_2(t), \ldots, s_D(t)]^T \\
# O(t) = [o_1(t), o_2(t), \ldots, o_D(t)]^T \\
# E(t) = [e_1(t), e_2(t), \ldots, e_D(t)]^T
# \]
#
# ### Step 2: OND Network Formulation
#
# The network nodes are \(V = \{S, O, E\}\), and edges \(E = \{(S, O), (O, E), (E, S)\}\).
#
# ### Step 3: Transformation Functions as OND Couplings
#
# The coupling functions representing transformations are:
#
# \[
# f_{SO}(S, O) = \alpha \cdot (S - O) \\
# f_{OE}(O, E) = \beta \cdot (O - E) \\
# f_{ES}(E, S) = \gamma \cdot (E - S)
# \]
#
# ### Step 4: Integration with Observational Dynamics (OD)
#
# To integrate the OD perspective, we can introduce a free energy function \(F(S, O, E)\) that encapsulates how each transformation aims to minimize the system's free energy.
#
# \[
# F(S, O, E) = \frac{1}{2} \sum_{i=1}^{D} \left( (s_i - o_i)^2 + (o_i - e_i)^2 + (e_i - s_i)^2 \right)
# \]
#
# ### Step 5: Introduce Non-Repeating Constraints
#
# We can introduce a regularization term \(\Phi(S, O, E)\) to enforce Penrose tiling constraints:
#
# \[
# F(S, O, E) = F(S, O, E) + \lambda \Phi(S, O, E)
# \]
#
# Here \(\lambda\) is a regularization parameter, and \(\Phi(S, O, E)\) can be defined in a way that promotes non-repeating patterns in \(S, O, E\).
#
# ### Step 6: Stochastic Differential Equations for Time Evolution
#
# The time evolution of \(S, O, E\) can be governed by stochastic differential equations that incorporate the coupling functions and aim to minimize \(F\):
#
# \[
# \frac{dS}{dt} = -\nabla F_{S} + \eta_S \\
# \frac{dO}{dt} = -\nabla F_{O} + \eta_O \\
# \frac{dE}{dt} = -\nabla F_{E} + \eta_E
# \]
#
# Here, \(\nabla F_{S}, \nabla F_{O}, \nabla F_{E}\) are the gradients of the free energy function with respect to \(S, O, E\), and \(\eta_S, \eta_O, \eta_E\) are stochastic noise terms.
#
# ### Step 7: Simulation and Validation
#
# With these equations in place, we can proceed to simulate this system numerically to explore its dynamics.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Parameters
D = 3  # Dimensionality of the state vectors
alpha, beta, gamma = 0.1, 0.2, 0.3  # Coupling coefficients
lambda_reg = 0.01  # Regularization parameter
T = 100  # Time steps
dt = 0.1  # Time resolution

# Initialize state vectors
S = np.random.randn(D)
O = np.random.randn(D)
E = np.random.randn(D)

# Placeholder for history
history_S = np.zeros((T, D))
history_O = np.zeros((T, D))
history_E = np.zeros((T, D))

# Define coupling functions
def f_SO(S, O):
    return alpha * (S - O)

def f_OE(O, E):
    return beta * (O - E)

def f_ES(E, S):
    return gamma * (E - S)

# Define free energy function and its gradient
def free_energy(S, O, E):
    return 0.5 * np.sum((S - O)**2 + (O - E)**2 + (E - S)**2)

def grad_free_energy(S, O, E):
    grad_S = S - O + E - S
    grad_O = O - E + S - O
    grad_E = E - S + O - E
    return grad_S, grad_O, grad_E

# Main loop
for t in range(T):
    # Record the history
    history_S[t] = S
    history_O[t] = O
    history_E[t] = E
    
    # Compute gradients of the free energy
    grad_S, grad_O, grad_E = grad_free_energy(S, O, E)
    
    # Update equations
    S = S - dt * grad_S + np.sqrt(dt)
    O = O - dt * grad_O + np.sqrt(dt) 
    E = E - dt * grad_E + np.sqrt(dt)

# Plotting
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Evolution of S')
plt.plot(history_S)
plt.xlabel('Time')
plt.ylabel('State')

plt.subplot(1, 3, 2)
plt.title('Evolution of O')
plt.plot(history_O)
plt.xlabel('Time')
plt.ylabel('State')

plt.subplot(1, 3, 3)
plt.title('Evolution of E')
plt.plot(history_E)
plt.xlabel('Time')
plt.ylabel('State')

plt.tight_layout()
plt.show()

def animate(i):
    plt.cla()
    plt.plot(history_S[:i], label='S')
    plt.plot(history_O[:i], label='O')
    plt.plot(history_E[:i], label='E')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('State')
    plt.title('Time: {}'.format(i))

fig = plt.figure(figsize=(15, 5))
anim = animation.FuncAnimation(fig, animate, frames=T, interval=10)
HTML(anim.to_html5_video())
# Out:
# <video width="1500" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Guiding Principles for a Universal System
#
# 1. **Objective Perception**: A universal system should be capable of objective perception. This can be modeled using three 'pillars': the subject, the object, and the environment. These pillars serve as the nodes in our OND framework.
#
# 2. **Transformational Dynamics**: The system should undergo a five-step transformation - Absorb, Transduce, Decide, Mediate, and Radiate. These transformations are the edges in our OND model, guiding the flow of information and state changes in the system.
#
# 3. **Non-repeating Form**: The system's transformations should be capable of generating non-repeating forms, adding an element of complexity and adaptability. This could be mathematically modeled using Penrose tilings or similar geometric or topological constructs.
#
# 4. **Free Energy Minimization**: Borrowing from thermodynamics and OD theory, the system should aim to minimize a 'free energy' function that captures the difference between its internal states and external inputs. This serves as a cost function guiding the system's dynamics.
#
# ### Mathematical Formalism
#
# 1. **State Vectors**: Each pillar (S for subject, O for object, E for environment) can be represented by a state vector in \( \mathbb{R}^D \), where \( D \) is the dimensionality of the state space.
#
# \[
# S, O, E \in \mathbb{R}^D
# \]
#
# 2. **Transformation Functions**: Each transformation step can be represented by a function capturing the change of state based on the current state and possibly external inputs. For example, the 'Absorb' step could be modeled as:
#
# \[
# f_{\text{Absorb}}(S, O) = \alpha \cdot (S - O)
# \]
#
# where \( \alpha \) is a coupling coefficient.
#
# 3. **Free Energy Function**: A free energy \( F(S, O, E) \) can be defined to capture the 'cost' of the system's current state configuration. This could be something like:
#
# \[
# F(S, O, E) = \frac{1}{2} \sum_{i \in \{S, O, E\}} \| i - \text{Mean}(S, O, E) \|_2^2
# \]
#
# 4. **Stochastic Differential Equations**: The evolution of the system can be modeled using stochastic differential equations (SDEs) that incorporate both deterministic dynamics and random fluctuations. This can be in line with the OND framework we discussed earlier.
#
# ### Implementation in OND and OD
#
# 1. **Nodes and Edges**: In OND, the pillars can be nodes and the transformations can be edges. Observer nodes can be included to model 'self-awareness' or meta-cognition.
#
# 2. **Thermodynamic Perspective**: In OD, the free energy function serves to tie the system's dynamics to thermodynamic principles, adding a layer of physical realism and also possibly explaining why such systems might naturally evolve to be 'intelligent'.
#
# 3. **Simulation**: Using OND's computational capabilities, we can simulate this system to observe its behavior under different conditions, providing us with insights into how universal cognition might emerge.

# %% [markdown]
# ## Step 1: Defining Mathematical Functions for Transformation Steps
#
# 1. **Absorb Function (\( A \)):** This function will define how a node absorbs information from its environment or neighboring nodes. It might take as input the current state of the node and the state of its environment or neighbors and return a new internal state for the node.
#     \[ A(x_i, x_{\text{env}}) \rightarrow x_i' \]
#
# 2. **Transduce Function (\( T \)):** This function will define how the absorbed information gets transduced or processed within the node.
#     \[ T(x_i') \rightarrow x_i'' \]
#
# 3. **Decide Function (\( D \)):** This will be a decision-making function that could be as simple as a threshold function or as complex as a neural network.
#     \[ D(x_i'') \rightarrow x_i''' \]
#
# 4. **Mediate Function (\( M \)):** This function will handle how the decision output is mediated within the system. It may involve some sort of optimization or energy minimization.
#     \[ M(x_i''', x_{\text{env}}) \rightarrow x_i'''' \]
#
# 5. **Radiate Function (\( R \)):** Finally, this function will handle how the node radiates the outcome of its mediation back into the environment or to its neighbors.
#     \[ R(x_i'''') \rightarrow x_{\text{env}}' \]
#
# ## Step 2: Integrate into OND Model
#
# Once we have these functions, we can integrate them into a network of nodes modeled using OND. Each node will implement these transformation steps as part of its state evolution.
#
# ## Step 3: Incorporate OD Principles
#
# We will also include thermodynamic principles from the OD framework to capture the flow of potential energy and entropy in the system.
#
# ## Step 4: Run Simulations
#
# With the model set up, we'll run simulations to observe how the system behaves under various conditions.
#
# ## Step 5: Data Analysis and Theoretical Refinement
#
# Based on the outcomes of the simulations, we'll analyze the data for patterns or emergent behaviors and refine our theoretical model as needed.

# %% [markdown]
# ## Step 1: Define Mathematical Functions for Transformation Steps

# %%
import numpy as np

# Define transformation functions

def absorb(x_i, x_env):
    """Absorb function: Absorbs information from the environment."""
    return x_i + 0.1 * (x_env - x_i)

def transduce(x_i):
    """Transduce function: Processes the absorbed information."""
    return np.sin(x_i)

def decide(x_i):
    """Decide function: Makes a decision based on the processed information."""
    return 1 if x_i > 0 else -1

def mediate(x_i, x_env):
    """Mediate function: Mediates the decision within the system."""
    return x_i * 0.9 + 0.1 * x_env

def radiate(x_i):
    """Radiate function: Radiates the mediated outcome back into the environment."""
    return x_i * 0.5

# Test the transformation functions
x_i = 0.5  # Initial state of the node
x_env = 1.0  # State of the environment

# Step 1: Absorb
x_i_prime = absorb(x_i, x_env)

# Step 2: Transduce
x_i_double_prime = transduce(x_i_prime)

# Step 3: Decide
x_i_triple_prime = decide(x_i_double_prime)

# Step 4: Mediate
x_i_quad_prime = mediate(x_i_triple_prime, x_env)

# Step 5: Radiate
x_env_prime = radiate(x_i_quad_prime)

x_i_prime, x_i_double_prime, x_i_triple_prime, x_i_quad_prime, x_env_prime
# Out:
# (0.55, 0.5226872289306592, 1, 1.0, 0.5)

# %% [markdown]
# ## Node State Vectors
#
# Here we have a simulation where each node goes through the five-step transformation—absorb, transduce, decide, mediate, and radiate—in a network of 10 nodes over 100 time steps. The environment also plays a role in these transformations.
#
# - **Node States Over Time**: This heatmap shows how the state of each node evolves over time. Each row corresponds to a node, and each column corresponds to a time step. The color indicates the state of the node.
#
# - **Environment Over Time**: This line plot shows how the state of the environment changes over time.
#
# As we can see, the states change and evolve over time, influenced by both the internal dynamics and the environment.
#
# This is a very basic simulation but serves as a foundation upon which more complex models, incorporating OD and OND principles, could be built. We can add more complex transformation functions, consider more intricate network topologies, or even introduce adaptive mechanisms.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Initialize parameters
num_nodes = 40
num_steps = 40
initial_state = np.random.rand(num_nodes)
environment = 0.5
state_history = np.random.rand(num_nodes, num_steps)
env_history = np.zeros(num_steps)

# Define transformation functions
def absorb(x, env):
    return x + 0.1 * env

def transduce(x):
    return np.sin(x)

def decide(x):
    return 1 if x > 0.9 else 0

def mediate(x, env):
    return x  # No change in this example

def radiate(x, env):
    return env + 0.1 * x

# Simulation loop
for t in range(num_steps):
    state_history[t] = initial_state
    env_history[t] = environment
    
    for i in range(num_nodes):
        initial_state[i] = absorb(initial_state[i], environment)
        initial_state[i] = transduce(initial_state[i])
        initial_state[i] = decide(initial_state[i])
        initial_state[i] = mediate(initial_state[i], environment)
        environment = radiate(initial_state[i], environment)

# Visualization
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Node States Over Time")
plt.imshow(state_history.T, aspect='auto', cmap='viridis')
plt.xlabel("Time")
plt.ylabel("Node")
plt.colorbar(label='State')

plt.subplot(1, 2, 2)
plt.title("Environment Over Time")
plt.plot(env_history)
plt.xlabel("Time")
plt.ylabel("Environment State")

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()
plt.show()

def animate(i):
    plt.cla()
    plt.imshow(state_history[:i].T, aspect='auto', cmap='viridis')
    plt.xlabel("Time")
    plt.ylabel("Node")
    plt.title("Time: {}".format(i))

fig = plt.figure(figsize=(10, 5))
# anim = animation.FuncAnimation(fig, animate, frames=num_steps, interval=10)
# HTML(anim.to_html5_video())

# %% [markdown]
# # State

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from scipy.spatial.distance import cdist

# Initialize parameters
num_nodes = 10  # Number of nodes
state_dim = 1  # Dimension of state vector for each node
T = 100  # Total time steps
dt = 0.1  # Time step size
threshold = 0.2  # State difference threshold for forming a connection

# Initialize states and network topology (fully connected initially)
states = np.random.rand(num_nodes, state_dim)
G = nx.complete_graph(num_nodes)

# Function to update states based on current topology
def update_states(states, G, dt):
    new_states = np.zeros_like(states)
    for i in range(len(states)):
        neighbors = list(G.neighbors(i))
        neighbor_states = states[neighbors]
        new_states[i] = states[i] + dt * np.sum(neighbor_states - states[i]) / len(neighbor_states)
    return new_states

# Function to update network topology based on current states
def update_topology(states, G, threshold):
    distances = cdist(states, states)
    for i in range(len(states)):
        for j in range(i+1, len(states)):
            if distances[i, j] < threshold and not G.has_edge(i, j):
                G.add_edge(i, j)
            elif distances[i, j] >= threshold and G.has_edge(i, j):
                G.remove_edge(i, j)

# Lists to store time evolution of states and network metrics
state_history = [states]
clustering_coeffs = [nx.average_clustering(G)]

# Main simulation loop
for t in range(T):
    # Update states
    states = update_states(states, G, dt)
    state_history.append(states)
    
    # Update topology based on new states
    update_topology(states, G, threshold)
    
    # Record metrics
    clustering_coeffs.append(nx.average_clustering(G))

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot state evolution for the first node
axes[0].plot([s[0] for s in state_history])
axes[0].set_title("State Evolution of Node 0")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("State")

# Plot clustering coefficient over time
axes[1].plot(clustering_coeffs)
axes[1].set_title("Average Clustering Coefficient Over Time")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Average Clustering Coefficient")

# Plot network topology at the end
plt.figure(figsize=(6, 6))
nx.draw(G, with_labels=True)
plt.title("Network Topology at the End of Simulation")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/11/gljh0sx11czcv67kxc_q6h5c0000gn/T/ipykernel_13024/3597346309.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   new_states[i] = states[i] + dt * np.sum(neighbor_states - states[i]) / len(neighbor_states)
# /var/folders/11/gljh0sx11czcv67kxc_q6h5c0000gn/T/ipykernel_13024/3597346309.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import networkx as nx
# load data into pandas dataframe
df = pd.read_csv('ml-latest-small/ratings.csv')[['userId', 'movieId', 'rating']]
# keep 100 users
df = df[df['userId'] < 10]
#df = df.pivot(index='userId', columns='movieId', values='rating')
print(df.head())
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
# Create an empty bipartite graph
B = nx.Graph()

# Add nodes with the node attribute "bipartite"
B.add_nodes_from(df['userId'].unique(), bipartite=0, label='user')
B.add_nodes_from(df['movieId'].unique(), bipartite=1, label='movie')

# Add edges only between nodes of opposite node sets
for _, row in df.iterrows():
    B.add_edge(row['userId'], row['movieId'], weight=row['rating'])

# Check if the graph is connected
nx.is_connected(B)
# Out:
# True

# %%
# Separate the nodes by their 'bipartite' attribute
user_nodes = {n for n, d in B.nodes(data=True) if d['bipartite'] == 0}
movie_nodes = set(B) - user_nodes

# Generate the user and movie projections
user_projection = nx.bipartite.projected_graph(B, user_nodes)
movie_projection = nx.bipartite.projected_graph(B, movie_nodes)

# Display some basic information about the projections
print(f"User Projection: {len(user_projection.nodes())} nodes, {len(user_projection.edges())} edges")
print(f"Movie Projection: {len(movie_projection.nodes())} nodes, {len(movie_projection.edges())} edges")
# Out:
# User Projection: 5 nodes, 4 edges
# Movie Projection: 863 nodes, 111707 edges

# %%
# Importing required libraries for visualization
import matplotlib.pyplot as plt

# Function to draw the network
def draw_network(G, title):
    pos = nx.spring_layout(G, seed=42)
    labels = {n: n for n in G.nodes()}
    nx.draw(G, pos, labels=labels, with_labels=True, node_color='skyblue', font_weight='bold', node_size=700, font_size=10)
    plt.title(title)
    plt.show()

# Draw the user and movie projections
draw_network(user_projection, "User Projection")
draw_network(movie_projection, "Movie Projection")

# %%
# Importing required libraries for feature extraction
from sklearn.preprocessing import StandardScaler

# Extracting features for users and movies based on their connections
def extract_features(G):
    features = {}
    for node in G.nodes():
        neighbors = list(G.neighbors(node))
        degree = G.degree(node)
        clustering_coefficient = nx.clustering(G, node)
        
        # Adding more network-based features could go here
        
        features[node] = [degree, clustering_coefficient]
    
    return features

# Extract features for user and movie projections
user_features = extract_features(user_projection)
movie_features = extract_features(movie_projection)

# Convert to DataFrame for better visibility and further processing
import pandas as pd

user_features_df = pd.DataFrame.from_dict(user_features, orient='index', columns=['Degree', 'Clustering Coefficient'])
movie_features_df = pd.DataFrame.from_dict(movie_features, orient='index', columns=['Degree', 'Clustering Coefficient'])

# Standardize the features (useful for machine learning models)
scaler = StandardScaler()
user_features_df_scaled = pd.DataFrame(scaler.fit_transform(user_features_df), columns=user_features_df.columns, index=user_features_df.index)
movie_features_df_scaled = pd.DataFrame(scaler.fit_transform(movie_features_df), columns=movie_features_df.columns, index=movie_features_df.index)

user_features_df_scaled, movie_features_df_scaled
# Out:
# (     Degree  Clustering Coefficient
#  9.0     2.0                     0.0
#  1.0    -0.5                     0.0
#  4.0    -0.5                     0.0
#  6.0    -0.5                     0.0
#  7.0    -0.5                     0.0,
#            Degree  Clustering Coefficient
#  2048.0 -0.205576                0.445597
#  1.0     3.241783               -3.361551
#  2.0     0.461655                0.349744
#  3.0     2.010584               -2.197171
#  4.0     0.445769                0.405556
#  ...          ...                     ...
#  4074.0 -0.340611                0.445597
#  2028.0 -0.205576                0.445597
#  2033.0 -0.205576                0.445597
#  2046.0 -0.205576                0.445597
#  9.0    -2.024574                0.445597
#
#  [863 rows x 2 columns])

# %% [markdown]
# Here we have a basic 2D visualization of two classes of data points (red and blue) with an observer (green 'x'). Currently, there are no dynamics; the points are static. The observer is also at a fixed position. This setup serves as a scaffold upon which we can build more complex dynamics, including the "absorb-transduce-decide-mediate-radiate" transformation sequence that we discussed earlier.

# %%
# Let's start by implementing a basic dynamics for the points and the observer.
# We will also implement the "absorb-transduce-decide-mediate-radiate" transformation sequence.

import numpy as np
import matplotlib.pyplot as plt

# Initialize parameters
num_points = 50
num_steps = 50
dt = 0.1  # Time step

# Initialize positions of red and blue points (each point is a 2D coordinate)
red_points = np.random.rand(num_points, 2) * 10
blue_points = np.random.rand(num_points, 2) * 10

# Initialize observer position
observer = np.array([5.0, 5.0])

# Initialize velocity (we'll keep it zero for now)
red_velocities = np.zeros_like(red_points)
blue_velocities = np.zeros_like(blue_points)
observer_velocity = np.zeros_like(observer)

# Function to update position based on velocity
def update_position(position, velocity, dt):
    return position + velocity * dt

# Dynamics function implementing the "absorb-transduce-decide-mediate-radiate" transformation sequence
def basic_dynamics(position, observer, dt):
    # Absorb: Observe the relative position to observer
    rel_position = position - observer
    
    # Transduce & Decide: Simple dynamics where we move towards the observer
    velocity = -0.1 * rel_position
    
    # Mediate & Radiate: Update position
    new_position = update_position(position, velocity, dt)
    
    return new_position

# Simulation loop
for step in range(num_steps):
    # Update red and blue points
    for i in range(num_points):
        red_points[i] = basic_dynamics(red_points[i], observer, dt)
        blue_points[i] = basic_dynamics(blue_points[i], observer, dt)
        
    # Update observer (we'll keep it static for now)
    # observer = basic_dynamics(observer, observer, dt)
    
    # Visualization
    if step % 5 == 0:  # Update plot every 5 steps
        plt.figure(figsize=(6, 6))
        plt.scatter(red_points[:, 0], red_points[:, 1], color='red')
        plt.scatter(blue_points[:, 0], blue_points[:, 1], color='blue')
        plt.scatter(observer[0], observer[1], color='green', marker='x', s=100)
        plt.xlim(0, 10)
        plt.ylim(0, 10)
        plt.title(f"Step: {step}")
        plt.show()

# %%
# Importing necessary libraries for our OND framework and simulation
import numpy as np
import matplotlib.pyplot as plt

# Define the initial state of our OND system with N nodes
N = 10  # Number of nodes
D = 5  # Dimensionality of state vectors, corresponding to the five steps (absorb, transduce, decide, mediate, radiate)

# Initialize state vectors for N nodes
state_vectors = np.random.rand(N, D)

# Function to simulate the five-step transformation for a given node
def five_step_transformation(node_state, neighbors_states):
    """
    Simulates the five-step transformation for a given node.
    
    Parameters:
    - node_state: 1D numpy array representing the state vector of the node
    - neighbors_states: 2D numpy array where each row is the state vector of a neighbor
    
    Returns:
    - new_node_state: 1D numpy array representing the updated state vector
    """
    
    # Step 1: Absorb (Here, we'll average the states of the neighbors)
    absorbed_state = np.mean(neighbors_states, axis=0)
    
    # Step 2: Transduce (Transform the absorbed state, for simplicity we'll just square it)
    transduced_state = absorbed_state ** 2
    
    # Step 3: Decide (Make a decision based on the transduced state, here we'll just sum it)
    decision = np.sum(transduced_state)
    
    # Step 4: Mediate (Update the node's own state based on the decision, here we add it)
    mediated_state = node_state + decision
    
    # Step 5: Radiate (Emit the new state, here it will be normalized)
    new_node_state = mediated_state / np.linalg.norm(mediated_state)
    
    return new_node_state

# Let's simulate this for 100 time steps
time_steps = 100

# Store the history of state vectors for visualization
history = np.zeros((time_steps, N, D))

for t in range(time_steps):
    history[t] = state_vectors
    
    # Update each node's state vector
    for i in range(N):
        # For simplicity, each node's neighbors are the two nodes next to it
        neighbors_indices = [(i-1) % N, (i+1) % N]
        neighbors_states = state_vectors[neighbors_indices]
        
        # Perform the five-step transformation
        new_state = five_step_transformation(state_vectors[i], neighbors_states)
        
        # Update the node's state
        state_vectors[i] = new_state

# Visualize the state vectors' evolution over time for the first dimension (corresponding to 'absorb')
plt.plot(history[:, :, 0])
plt.title('Evolution of the "Absorb" Dimension Over Time')
plt.xlabel('Time Step')
plt.ylabel('State Value')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize parameters
num_nodes = 10
num_steps = 100
initial_state = np.random.rand(num_nodes, 5)  # 5 dimensions for each node
state = np.zeros((num_steps, num_nodes, 5))
state[0] = initial_state
dt = 0.1

# Define transformation functions for each of the 5 steps
def absorb(x):
    return np.sin(x)

def transduce(x, neighbors):
    return np.mean(neighbors, axis=0) + x

def decide(x):
    return 1 / (1 + np.exp(-x))

def mediate(x, neighbors):
    return np.tanh(np.mean(neighbors, axis=0) - x)

def radiate(x):
    return x ** 2

# Simulation loop
for t in range(1, num_steps):
    for i in range(num_nodes):
        neighbors = state[t-1][(i-1)%num_nodes : (i+2)%num_nodes]
        x = state[t-1, i]
        
        # Apply the five-step transformations
        x = absorb(x)
        x = transduce(x, neighbors)
        x = decide(x)
        x = mediate(x, neighbors)
        x = radiate(x)
        
        state[t, i] = x

# Plotting the evolution of the "Absorb" dimension for all nodes
plt.figure(figsize=(10, 6))
for i in range(num_nodes):
    plt.plot(state[:, i, 0], label=f'Node {i+1}')
plt.title('Evolution of "Absorb" Dimension Over Time')
plt.xlabel('Time Step')
plt.ylabel('State Value')
plt.legend()
plt.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize parameters
n_nodes = 10
n_steps = 100
threshold = 0.5

# Initialize state vectors
state_vectors = np.random.rand(n_nodes)

# Initialize plot
plt.figure(figsize=(10, 6))

# Simulation loop
for t in range(n_steps):
    # Plot current state
    plt.plot([t]*n_nodes, state_vectors, 'bo')
    
    # Update rule incorporating 'Decide' step
    for i in range(n_nodes):
        if state_vectors[i] > threshold:
            state_vectors[i] = 1 - state_vectors[i]  # Flip the state

    # Random walk as a placeholder for more complex dynamics
    state_vectors += np.random.normal(0, 0.1, n_nodes)
    
    # Keep within bounds [0, 1]
    state_vectors = np.clip(state_vectors, 0, 1)

# Finalize plot
plt.xlabel('Time step')
plt.ylabel('State')
plt.title('State Evolution with Decision-Making')
plt.grid(True)
plt.show()

# %%
# Let's extend the model to include the "Mediate" and "Radiate" steps.
# For simplicity, let's consider that mediation involves some form of average with the neighbors' states.
# Radiate will simply be the new state after all transformations.

import numpy as np
import matplotlib.pyplot as plt

# Initialize parameters
N = 10  # Number of nodes
T = 100  # Number of time steps
state = np.random.rand(N)  # Initial state (Absorb)
threshold = 0.5  # Threshold for decision (Decide)
alpha = 0.2  # Parameter for mediation (Mediate)

# Store states over time
state_over_time = np.zeros((N, T))

# Simulate dynamics
for t in range(T):
    state_over_time[:, t] = state
    
    # Step 1: Absorb (Already represented by the initial state)
    
    # Step 2: Transduce (Here, represented by a random walk)
    noise = np.random.normal(0, 0.1, N)
    state += noise
    
    # Step 3: Decide (Flip the state if it crosses the threshold)
    state[state > threshold] = 1 - state[state > threshold]
    
    # Step 4: Mediate (Influence of neighbors' state; for simplicity, let's consider nearest neighbors)
    state = (1 - alpha) * state + alpha * np.roll(state, shift=1, axis=0)
    
    # Step 5: Radiate (New state after transformations)
    # This will be the state for the next iteration

# Visualize the state dynamics
plt.figure(figsize=(10, 8))
plt.imshow(state_over_time, aspect='auto', cmap='viridis')
plt.colorbar(label='State Value')
plt.xlabel('Time')
plt.ylabel('Node')
plt.title('State Dynamics with Five-Step Transformation')
plt.show()

# %%
# Import necessary libraries
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import numpy as np

# Fetch the MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist["data"], mnist["target"]

# Convert the labels to integers
y = y.astype(np.int8)

# Normalize the pixel values to the range [0, 1]
X = X / 255.0

# Reshape the data to have the images in a 28x28 grid
X_reshaped = X.reshape(-1, 28, 28)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/11/gljh0sx11czcv67kxc_q6h5c0000gn/T/ipykernel_13024/1652246596.py in ?()
#      13 # Normalize the pixel values to the range [0, 1]
#      14 X = X / 255.0
#      15
#      16 # Reshape the data to have the images in a 28x28 grid
# ---> 17 X_reshaped = X.reshape(-1, 28, 28)
#      18
#      19 # Split the data into training and test sets
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic dataset
np.random.seed(0)
X = np.random.rand(1000, 2)  # Features
y = (X[:, 0] + X[:, 1] > 1).astype(int)  # Labels

# Plot the synthetic dataset
plt.figure(figsize=(8, 8))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], label='Class 0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label='Class 1')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Synthetic Dataset')
plt.show()

# %%
# Import necessary libraries
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Define the 5-step transformation function
def five_step_transform(y, t, weights):
    absorb, transduce, decide, mediate, radiate = y
    
    # Initialize derivatives
    dydt = np.zeros(5)
    
    # Absorb: Incorporate external information
    dydt[0] = weights[0] * (transduce - absorb)
    
    # Transduce: Convert absorbed information for decision-making
    dydt[1] = weights[1] * (absorb - transduce)
    
    # Decide: Make a decision based on transduced information
    dydt[2] = weights[2] * (transduce - decide)
    
    # Mediate: Prepare the decision for external output
    dydt[3] = weights[3] * (decide - mediate)
    
    # Radiate: Emit the decision as an external action
    dydt[4] = weights[4] * (mediate - radiate)
    
    return dydt

# Initial conditions (absorb, transduce, decide, mediate, radiate)
y0 = [0, 0, 0, 0, 0]

# Time grid for integration
t = np.linspace(0, 2, 10)

# Weights for the transitions (random for demonstration)
weights = np.random.rand(5)

# Solve the differential equations
solution = odeint(five_step_transform, y0, t, args=(weights,))

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t, solution[:, 0], label='Absorb')
plt.plot(t, solution[:, 1], label='Transduce')
plt.plot(t, solution[:, 2], label='Decide')
plt.plot(t, solution[:, 3], label='Mediate')
plt.plot(t, solution[:, 4], label='Radiate')
plt.legend(loc='best')
plt.xlabel('Time')
plt.ylabel('State Variables')
plt.title('Five-Step Transformation Model')
plt.show()
